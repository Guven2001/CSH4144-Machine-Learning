# %%
import pandas as pd
import numpy as np
 
#to read the data in the csv file
data = pd.read_csv("FSData.csv")
print(data,"n")
 
#making an array of all the attributes
d = np.array(data)[:,:-1]
print("n The attributes are: ",d)
 
#segragating the target that has positive and negative examples
target = np.array(data)[:,-1]
print("n The target is: ",target)
 
#training function to implement find-s algorithm
def train(c,t):
    for i, val in enumerate(t):
        if val == "Yes":
            specific_hypothesis = c[i].copy()
            break
             
    for i, val in enumerate(c):
        if t[i] == "Yes":
            for x in range(len(specific_hypothesis)):
                if val[x] != specific_hypothesis[x]:specific_hypothesis[x] = '?'
                else:
                    pass
                 
    return specific_hypothesis
 
#obtaining the final hypothesis
print("n The final hypothesis is:",train(d,target))
# Out:
#       Time Weather Temperate Company Humidity    Wind Goes
# 0  Morning   Sunny      Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy      Cold      No     Mild  Normal   No
# 2  Morning   Sunny  Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny      Cold     Yes     High  Strong  Yes n
# n The attributes are:  [['Morning' 'Sunny' 'Warm' 'Yes' 'Mild' 'Strong']
#  ['Evening' 'Rainy' 'Cold' 'No' 'Mild' 'Normal']
#  ['Morning' 'Sunny' 'Moderate' 'Yes' 'Normal' 'Normal']
#  ['Evening' 'Sunny' 'Cold' 'Yes' 'High' 'Strong']]
# n The target is:  ['Yes' 'No' 'Yes' 'Yes']
# n The final hypothesis is: ['?' 'Sunny' '?' 'Yes' '?' '?']

# %%
# Find-S Algorithm 
import pandas as pd
import numpy as np

# Read the data
data = pd.read_csv("FSData.csv")
print(data, "\n")

print('\n')

# Making an array of all attribute columns (excluding the target/label column)
d = np.array(data)[:, :-1]  # 🔧 FIXED: Changed from [:, :1] to include all input attributes
print("First attributes are:\n", d)
print('\n')

# Separating the target (label)
target = np.array(data)[:, 1]  # This is optional — you're overwriting it below anyway
print("Second attribute is:", target)
print('\n')

# Correct target: selecting the last column as label
target = np.array(data)[:, -1]
print("Target is:", target)

# Training function to implement Find-S algorithm
def train(c, t):
    for i, val in enumerate(t):
        if val == "Yes":
            specific_hypothesis = c[i].copy()
            break
            
    for i, val in enumerate(c):  # 🔧 FIXED: iterate over concepts instead of targets
        if t[i] == "Yes":
            for x in range(len(specific_hypothesis)):
                if val[x] != specific_hypothesis[x]:
                    specific_hypothesis[x] = '?'
                else:
                    pass
                
    return specific_hypothesis

# Obtaining the final hypothesis
print("\nThe final hypothesis is:", train(d, target))
# Out:
#       Time Weather Temperate Company Humidity    Wind Goes
# 0  Morning   Sunny      Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy      Cold      No     Mild  Normal   No
# 2  Morning   Sunny  Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny      Cold     Yes     High  Strong  Yes
#
#
#
# First attributes are:
#  [['Morning' 'Sunny' 'Warm' 'Yes' 'Mild' 'Strong']
#  ['Evening' 'Rainy' 'Cold' 'No' 'Mild' 'Normal']
#  ['Morning' 'Sunny' 'Moderate' 'Yes' 'Normal' 'Normal']
#  ['Evening' 'Sunny' 'Cold' 'Yes' 'High' 'Strong']]
#
#
# Second attribute is: ['Sunny' 'Rainy' 'Sunny' 'Sunny']
#
#
# Target is: ['Yes' 'No' 'Yes' 'Yes']
#
# The final hypothesis is: ['?' 'Sunny' '?' 'Yes' '?' '?']

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('FSData.csv')
print('data\n',data)
print('\n')
concepts = np.array(data.iloc[:, 0:-1])
print('concept:',concepts)
print('\n')
target = np.array(data.iloc[:, -1])
print('target:',target)
print('\n')

def learn(concepts, target):
    specific_h = concepts[0].copy()
    general_h = [["?" for i in range(len(specific_h))] for i in range(len(specific_h))]
    
    for i, h in enumerate(concepts):
        if target[i].lower() == "yes":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    specific_h[x] = '?'
                    general_h[x][x] = '?'
        elif target[i].lower() == "no":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'
                    
    # Remove all general hypotheses that are all '?'
    indices = [i for i, val in enumerate(general_h) if val == ['?'] * len(specific_h)]
    for i in sorted(indices, reverse=True):
        general_h.pop(i)
    
    return specific_h, general_h

s_final, g_final = learn(concepts, target)

print("Final Specific_h:", s_final)
print("Final General_h:", g_final)
# Out:
# data
#        Time Weather Temperate Company Humidity    Wind Goes
# 0  Morning   Sunny      Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy      Cold      No     Mild  Normal   No
# 2  Morning   Sunny  Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny      Cold     Yes     High  Strong  Yes
#
#
# concept: [['Morning' 'Sunny' 'Warm' 'Yes' 'Mild' 'Strong']
#  ['Evening' 'Rainy' 'Cold' 'No' 'Mild' 'Normal']
#  ['Morning' 'Sunny' 'Moderate' 'Yes' 'Normal' 'Normal']
#  ['Evening' 'Sunny' 'Cold' 'Yes' 'High' 'Strong']]
#
#
# target: ['Yes' 'No' 'Yes' 'Yes']
#
#
# Final Specific_h: ['?' 'Sunny' '?' 'Yes' '?' '?']
# Final General_h: [['?', 'Sunny', '?', '?', '?', '?'], ['?', '?', '?', 'Yes', '?', '?']]

# %%
import numpy as np
import pandas as pd

# Load the dataset
data = pd.read_csv('FSData.csv')

# Separate attributes (concepts) and target labels
concepts = np.array(data.iloc[:, 0:-1])
target = np.array(data.iloc[:, -1])

def learn(concepts, target):
    # Initialize the most specific hypothesis to the first positive example
    specific_h = concepts[0].copy()
    
    # Initialize the most general hypotheses to all '?'
    general_h = [["?" for _ in range(len(specific_h))] for _ in range(len(specific_h))]

    for i, h in enumerate(concepts):
        if target[i].lower() == "yes":
            # For positive examples, generalize specific_h if needed
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    specific_h[x] = '?'
                    general_h[x][x] = '?'
        elif target[i].lower() == "no":
            # For negative examples, specialize general_h
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'

    # Remove fully general hypotheses from general_h
    indices = [i for i, val in enumerate(general_h) if val == ['?'] * len(specific_h)]
    for i in sorted(indices, reverse=True):
        general_h.pop(i)

    return specific_h, general_h

# Learn hypotheses from data
s_final, g_final = learn(concepts, target)

# Print final hypotheses
print("Final Specific Hypothesis:", s_final)
print("Final General Hypotheses:", g_final)
# Out:
# Final Specific Hypothesis: ['?' 'Sunny' '?' 'Yes' '?' '?']
# Final General Hypotheses: [['?', 'Sunny', '?', '?', '?', '?'], ['?', '?', '?', 'Yes', '?', '?']]
